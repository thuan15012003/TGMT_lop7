# %%
# !pip install pillow

# %%
from PIL import Image

# %%
dir = 'C:/Users/hinhanh'

# %%
image_path = dir + '/hoa.JPG'
print(image_path)
# Out:
# C:/Users/hinhanh/hoa.JPG

# %%
imghinhanh = Image.open(image_path)

# %%
display(imghinhanh)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x900>

# %%
print("Định dạng ảnh: "+ imghinhanh.format)
# Out:
# Định dạng ảnh: JPEG

# %%
print("kích cỡ  ảnh: ", imghinhanh.size)
# Out:
# kích cỡ  ảnh:  (1200, 900)

# %%
new_img_hinhanh_path = dir + '/new_hoa.JPG'
new_img_png_hinhanh_path = dir + '/new_hoa.JPG'
imghinhanh.save(new_img_hinhanh_path)
imghinhanh.save(new_img_png_hinhanh_path)

# %%
imghinhanh.close()
