# %%
import matplotlib.pyplot as plt

# %%
x = [1, 2, 3, 4, 5]
y = [10, 16, 20, 30, 25]

x1 = [1, 2, 3, 4, 5]
y1 = [20, 15, 8, 9, 20]

plt.plot(x, y, 'bo-', label='Data') 
plt.plot(x1, y1, marker='o', color='r', linestyle='-', label='Data-1')
plt.legend() 
plt.xlabel('truc x') 
plt.ylabel('truc y')
plt.show()

# %%
categories = ['A', 'B', 'C', 'D', 'E']
values ​​= [15, 10, 25, 12, 18]

plt.bar(categories, values, color='g', alpha=0.6)
plt.xlabel('danh muc') 
plt.ylabel('gia tri') 
plt.show()
# Out:
#   Cell In[29], line 2
#     values ​​= [15, 10, 25, 12, 18]
#            ^
# SyntaxError: invalid non-printable character U+200B

# %%
my_labels = ['A', 'B', 'C', 'D']
sizes = [15, 30, 45, 10]
my_colors = ['red', 'green', 'blue', 'yellow']

plt.pie(sizes, labels=my_labels, colors = my_colors, autopct='%1.1f%%')
plt.show()

# %%
import matplotlib.pyplot as plt
x = [1, 2, 3, 4, 5]
y = [10, 16, 20, 30, 25]

plt.scatter(x, y, c='r', marker='o', label='Du lieu') 
plt.xlabel('Trục X')
plt.ylabel('Trục Y')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
data = [15, 18, 22, 30, 35, 45, 50, 55, 65]
plt.boxplot(data) 
plt.title('Bieu đồ hộp')
plt.ylabel('gia tri')
plt.show()

# %%
import matplotlib.pyplot as plt
data = [15, 18, 22, 30, 35, 45, 50, 55, 65]
plt.violinplot(data)
plt.title('bieu do violin')
plt.ylabel('gia tri')
plt.show()

# %%
# !pip install wordcloud
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text = "Python is an amazing language for data visualization and word clouds."

wordcloud = WordCloud(width=800, height=400).generate (text)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Cbieu do dam may tu van ban vi du')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
categories = ['A', 'B', 'C', 'D', 'E']
values = [5, 4, 3, 7, 6]

N = len(categories)
values += values[:1]
angles = [n / float(N) * 2 * np.pi for n in range(n)]
angles += angles[:1]
plt.polar(angles, values, 'o-', linewidth=2)
plt.fill(angles, values, 'b', alpha=0.1)
plt.title('Biểu đồ radar mẫu')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 7
#       5 N = len(categories)
#       6 values += values[:1]
# ----> 7 angles = [n / float(N) * 2 * np.pi for n in range(n)]
#       8 angles += angles[:1]
#       9 plt.polar(angles, values, 'o-', linewidth=2)
#
# NameError: name 'n' is not defined
