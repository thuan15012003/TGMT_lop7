# %%
from PIL import Image
from imgtools import *
from IPython.display import display

# %%
my_path = 'C:/Users/hinhanh/02.jpg'

# %%
img = load_image(my_path)
           # Resize
           # img = imgresize((250,250))

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=602x339>

# %%
gray_image = img.convert("L")
display(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=602x339>

# %%
red_band, green_band, blue_band = img.split()
display(red_band)
display(green_band)
display(blue_band)
# Out:
# <PIL.Image.Image image mode=L size=602x339>
# <PIL.Image.Image image mode=L size=602x339>
# <PIL.Image.Image image mode=L size=602x339>

# %%
merged_image = Image.merge("RGB", (red_band, green_band, blue_band))
display(merged_image)
# Out:
# <PIL.Image.Image image mode=RGB size=602x339>
