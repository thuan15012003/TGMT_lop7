# %%
import matplotlib as mpt
import matplotlib.pyplot as plt
from PIL import Image

# %%
my_path = 'C:/Users/hinhanh/02.jpg'
im = Image.open(my_path)
display(im)
plt.imshow(im)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=602x339>

# %%
x = [1, 2, 3, 4, 5]
y = [10, 16, 20, 30, 25]
plt.plot(x,y)
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [10, 16, 20, 30, 25]
plt.plot(x,y, color='red')
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [10, 16, 20, 30, 25]
plt.plot(x,y, color='red')
plt.title('vi du ve bieu do')
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [10, 16, 20, 30, 25]
plt.plot(x,y, color='red')
plt.title('vi du ve bieu do')
plt.axis('off')
plt.show()

# %%
im = Image.open(my_path)
x = [100, 100, 400, 400]
y = [200, 300, 200, 300]
plt.imshow(im)
plt.plot(x, y, 'bo--')
plt.show()
